# %%
from pymongo import MongoClient
conn = MongoClient('35.164.239.112', 27017)

# %%
import pymongo as pm
import boto3
import json
import sys
from pymongo import MongoClient

# %%
conn2 = MongoClient('mongodb://admin:123456@35.164.239.112:27017/sa')

# %%
db = conn.eyebnb_1
db.collection_names()
# Out:
# []

# %%
datas = [
        {'_id':1, 'data':{'12':3,'232':2}},        
        {'_id':2, 'data':22},
        {'_id':3, 'data':'cc'}      
    ]

# %%
data_base_json_full = 'https://s3-us-west-2.amazonaws.com/chen-gal-test/AirbnbData/Boston-Massachusetts-US/ws_data/webscrapted.json'
database_json_short = 'AirbnbData/Boston-Massachusetts-US/ws_data/webscrapted.json'
bucket_name = "chen-gal-test"
s3 = boto3.client("s3")

response = s3.get_object(Bucket=bucket_name,
                             Key=database_json_short)
fake_database= json.loads(response['Body'].read())

# %%
db = conn['eyebnb_1']
db.collection_names()
# Out:
# []

# %%
books = db.eye_1

# %%
z = books.find_one()

# %%
dict_temp = []
for j in mongolist:

    tmp = j[1].update({'Id_1':j[0]})

    dict_temp.append(j[1])

# %%
dict_temp[1]
# Out:
# {'ID': '13937181',
#  'Id_1': '13937181',
#  '_id': ObjectId('5b048f288d07421673d03509'),
#  'apt_name': 'Guest Room in Cozy Home',
#  'info': {'canonical_url': 'https://www.airbnb.com/rooms/13937181',
#   'coordinate': [42.27636367614069, -71.13643292507432],
#   'country_code': 'US',
#   'host_about': 'I am a kindergarten teacher working for the Boston Public Schools.  I have three adult daughters, two of which live on their own and the youngest goes to college out of state.',
#   'host_id': 82861960,
#   'host_member_profile': '/users/show/82861960',
#   'host_member_since': 'July 2016',
#   'host_name': 'Lelia',
#   'id': 13937181,
#   'localized_city': 'Boston',
#   'overall_rating': 5,
#   'photo_urls': ['https://a0.muscache.com/im/pictures/02f47ff6-c197-4c42-bee9-b96edc4c4342.jpg?aki_policy=large',
#    'https://a0.muscache.com/im/pictures/45b00d32-fdf3-404c-a381-afb142d89144.jpg?aki_policy=large',
# ...

# %%
books.insert_many(dict_temp)

# %%
type(fake_database)
# Out:
# dict

# %%
mongolist = []

# %%
for x in fake_database.items():
    mongolist.append(x)

# %%
z[2]['data']['12']
# Out:
# 3

# %%
fake_database.items()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-78e38bfe1029> in <module>()
# ----> 1 z = fake_database[10]
#
# KeyError: 10

# %%
dict_temp = []
for j in mongolist[0:5]:

    tmp = j[1].update({'Id_1':j[0]})

    dict_temp.append(j[1])

# %%
for x in books.find():
    print(x)
# Out:
# {'_id': ObjectId('5b048f288d07421673d03508'), 'apt_name': 'Charming Boston Residential', 'url': 'https://www.airbnb.com/rooms/20872145', 'info': [], 'ID': '20872145', 'Id_1': '20872145'}
# ...

# %%
url = books.find_one({'Id_1':'3575220'})['info']['canonical_url']

# %%
apt_name
# Out:
# 'https://www.airbnb.com/rooms/3575220'
